# %% [markdown]
# <a href="https://colab.research.google.com/github/BotSonu/Data-Analysis/blob/main/Fifa_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Read the file into a variable fifa_data
fifa_data = pd.read_csv("/content/fifa.csv")

# %%
# Showing the dataframe
fifa_data
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %% [markdown]
# # Examine & Analyse the data

# %%
# Print the 1st 5 rows of the data
fifa_data.head()
# Out:
#          Date   ARG  BRA   ESP   FRA  GER  ITA
# 0  1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1  1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 2  1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 3  1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 4  1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
# Print the last 5 rows of the data
fifa_data.tail()
# Out:
#            Date  ARG  BRA   ESP  FRA  GER   ITA
# 281  2018-02-15  4.0  2.0   6.0  9.0  1.0  14.0
# 282  2018-03-15  4.0  2.0   6.0  9.0  1.0  14.0
# 283  2018-04-12  5.0  2.0   8.0  7.0  1.0  20.0
# 284  2018-05-17  5.0  2.0   8.0  7.0  1.0  20.0
# 285  2018-06-07  5.0  2.0  10.0  7.0  1.0  19.0

# %%
# Getting access to the shape of the data
fifa_data.shape
# Out:
# (286, 7)

# %%
# Getting access to the index of the data
fifa_data.index
# Out:
# RangeIndex(start=0, stop=286, step=1)

# %%
# Print the n rows of the data
fifa_data.head(10)
# Out:
#          Date   ARG  BRA   ESP   FRA  GER   ITA
# 0  1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1  1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2  1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3  1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4  1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# 5  1994-02-15   9.0  2.0   6.0  14.0  1.0   7.0
# 6  1994-03-15   8.0  2.0   6.0  15.0  1.0  11.0
# 7  1994-04-19  10.0  1.0   7.0  15.0  2.0  13.0
# 8  1994-05-17   6.0  1.0   9.0  17.0  2.0  16.0
# 9  1994-06-14   8.0  3.0   5.0  13.0  1.0   4.0

# %%
# Getting access to the columns of the data
fifa_data.columns
# Out:
# Index(['Date', 'ARG', 'BRA', 'ESP', 'FRA', 'GER', 'ITA'], dtype='object')

# %%
# Selecting one column
fifa_data["Date"]
# Out:
# 0      1993-08-08
# 1      1993-09-23
# 2      1993-10-22
# 3      1993-11-19
# 4      1993-12-23
#           ...
# 281    2018-02-15
# 282    2018-03-15
# 283    2018-04-12
# 284    2018-05-17
# 285    2018-06-07
# Name: Date, Length: 286, dtype: object

# %%
# Selecting two or more columns
fifa_data[["Date","ARG",'ITA']]
# Out:
#            Date   ARG   ITA
# 0    1993-08-08   5.0   2.0
# 1    1993-09-23  12.0   2.0
# 2    1993-10-22   9.0   3.0
# 3    1993-11-19   9.0   1.0
# 4    1993-12-23   8.0   2.0
# ..          ...   ...   ...
# 281  2018-02-15   4.0  14.0
# 282  2018-03-15   4.0  14.0
# 283  2018-04-12   5.0  20.0
# 284  2018-05-17   5.0  20.0
# 285  2018-06-07   5.0  19.0
#
# [286 rows x 3 columns]

# %%
# Obtaining the data type
type(fifa_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Data type of each column
fifa_data.dtypes
# Out:
# Date     object
# ARG     float64
# BRA     float64
# ESP     float64
# FRA     float64
# GER     float64
# ITA     float64
# dtype: object

# %%
# Data type of that one column
type(fifa_data["Date"])
# Out:
# pandas.core.series.Series

# %%
# Creating an array of 286 elements
new_col = np.arange(0,286)

# %%
# Creating random integer numbers between 1 to 100
new_col = np.random.randint(1, 100, size = 286)

# %%
# Creating random float numbers between 1 to 100
new_col = np.random.uniform(1, 100, size = 286)

# %%
# Adding a new column to a dataset with an array
fifa_data['new_col'] = new_col

# %%
# Showing the newly created data
fifa_data
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA    new_col
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0  30.811449
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0  40.993570
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0  22.102142
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0  15.693590
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0  99.928534
# ..          ...   ...  ...   ...   ...  ...   ...        ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0  71.535366
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0  19.298192
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0  23.881634
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0  22.351962
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0  24.969707
#
# [286 rows x 8 columns]

# %%
# Another methode of rounding numbers of new_col
fifa_data['new_col'].round(2)
# Out:
# 0      30.81
# 1      40.99
# 2      22.10
# 3      15.69
# 4      99.93
#        ...
# 281    71.54
# 282    19.30
# 283    23.88
# 284    22.35
# 285    24.97
# Name: new_col, Length: 286, dtype: float64

# %%
# Showing the info of the dataset
fifa_data.info
# Out:
# <bound method DataFrame.info of            Date   ARG  BRA   ESP   FRA  GER   ITA    new_col
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0  30.811449
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0  40.993570
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0  22.102142
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0  15.693590
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0  99.928534
# ..          ...   ...  ...   ...   ...  ...   ...        ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0  71.535366
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0  19.298192
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0  23.881634
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0  22.351962
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0  24.969707
#
# [286 rows x 8 columns]>

# %%
# Select a column and find total sum
fifa_data['ARG'].sum()
# Out:
# 1560.0

# %%
# Select a row and find total sum
fifa_data['ARG'] + fifa_data['ITA']
# Out:
# 0       7.0
# 1      14.0
# 2      12.0
# 3      10.0
# 4      10.0
#        ...
# 281    18.0
# 282    18.0
# 283    25.0
# 284    25.0
# 285    24.0
# Length: 286, dtype: float64

# %%
# Calculating the average score and assigning the result to a new column
fifa_data['Average'] = (fifa_data['ARG'] + fifa_data['ITA'])/2
fifa_data
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA    new_col  Average
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0  30.811449      3.5
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0  40.993570      7.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0  22.102142      6.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0  15.693590      5.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0  99.928534      5.0
# ..          ...   ...  ...   ...   ...  ...   ...        ...      ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0  71.535366      9.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0  19.298192      9.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0  23.881634     12.5
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0  22.351962     12.5
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0  24.969707     12.0
#
# [286 rows x 9 columns]

# %%
# Describe the basic statistics of the dataset
fifa_data.describe()
# Out:
#               ARG         BRA         ESP         FRA         GER         ITA  \
# count  286.000000  286.000000  286.000000  286.000000  286.000000  286.000000
# mean     5.454545    3.171329    5.321678    8.958042    5.104895    8.353147
# std      4.012659    3.620897    3.908787    6.822948    4.354813    4.514822
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    1.000000    2.000000    3.000000    2.000000    4.000000
# 50%      5.000000    1.500000    5.000000    7.000000    4.000000    8.000000
# 75%      7.000000    4.000000    8.000000   15.000000    5.000000   12.000000
# max     24.000000   22.000000   25.000000   27.000000   22.000000   20.000000
#
#           new_col     Average
# count  286.000000  286.000000
# mean    49.061626    6.903846
# std     29.184042    2.810448
# min      1.786239    1.500000
# 25%     23.667278    5.000000
# 50%     47.070801    6.500000
# 75%     75.620873    8.500000
# ...

# %%
# Rounding the values of the data set
round(fifa_data.describe(),2)
# Out:
#           ARG     BRA     ESP     FRA     GER     ITA  new_col  Average
# count  286.00  286.00  286.00  286.00  286.00  286.00   286.00   286.00
# mean     5.45    3.17    5.32    8.96    5.10    8.35    49.06     6.90
# std      4.01    3.62    3.91    6.82    4.35    4.51    29.18     2.81
# min      1.00    1.00    1.00    1.00    1.00    1.00     1.79     1.50
# 25%      3.00    1.00    2.00    3.00    2.00    4.00    23.67     5.00
# 50%      5.00    1.50    5.00    7.00    4.00    8.00    47.07     6.50
# 75%      7.00    4.00    8.00   15.00    5.00   12.00    75.62     8.50
# max     24.00   22.00   25.00   27.00   22.00   20.00    99.93    16.00

# %%
# Length of the dataset [no. of rows]
len(fifa_data)
# Out:
# 286

# %%
# Highest index of the dataset
max(fifa_data.index)
# Out:
# 285

# %%
# Lowest index of the dataset
min(fifa_data)
# Out:
# 'ARG'
